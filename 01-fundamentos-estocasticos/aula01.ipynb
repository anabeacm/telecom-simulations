# %%
import numpy as np
import matplotlib.pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
np.random.randn()
# Out:
# -1.5638999526927075

# %%
x = np.random.randn(10)

x
# Out:
# array([-0.46990375, -0.65527543, -1.39796831,  1.13138591, -1.88945301,
#        -0.30112337,  0.8073701 ,  0.24604012, -0.72873537,  1.41648525])

# %%
x = np.random.randn(1000)

# %%
x
# Out:
# array([ 7.46631054e-02, -7.95054546e-01, -1.29509863e+00,  6.97260885e-01,
#        -3.24868273e-01, -2.79821004e+00,  4.18430174e-01,  5.38759379e-01,
#        -1.44563150e-01, -1.11293397e-01, -4.75545914e-02, -1.15021833e+00,
#        -8.37712697e-01,  4.34801661e-01,  9.63357120e-01,  1.89965814e-01,
#        -8.03899846e-01,  1.09498628e+00,  8.02814170e-01,  3.72755060e-01,
#        -7.48216522e-01, -1.88984637e+00, -7.65731554e-01,  8.41299893e-01,
#         1.37380125e+00,  3.10910300e-01, -1.79555391e-01, -3.94187760e-01,
#         7.74305631e-01, -7.44334600e-01, -2.01626508e-01, -3.20326199e-01,
#         1.39851754e+00,  7.97563084e-01,  7.00828082e-01,  2.79358243e-01,
#         6.28981470e-01,  1.23480587e+00, -4.15130749e-01, -1.21964190e+00,
#         2.30687930e+00, -5.06470349e-01,  4.73616889e-01,  7.21044224e-03,
#        -4.38148873e-01, -9.55720392e-01,  2.37301460e-01, -2.21336970e-02,
# ...

# %%
len(x)
# Out:
# 1000

# %%
x.min(), x.max()
# Out:
# (np.float64(-2.944840903602393), np.float64(3.470284077062118))

# %%
x = np.random.randn(1000)

x.min(), x.max()
# Out:
# (np.float64(-2.8039913148785693), np.float64(3.5158447686722925))

# %%
print(x.mean())
# Out:
# 0.0012770484797198964

# %%
plt.hist(x, bins=40)
# Out:
# (array([ 3.,  1.,  5.,  2.,  6., 13., 13., 17., 29., 32., 28., 32., 46.,
#         54., 56., 68., 59., 56., 73., 67., 41., 50., 30., 50., 30., 36.,
#         25., 18., 21.,  6.,  7.,  8.,  6.,  6.,  2.,  2.,  0.,  1.,  0.,
#          1.]),
#  array([-2.80399131, -2.64599541, -2.48799951, -2.33000361, -2.17200771,
#         -2.0140118 , -1.8560159 , -1.69802   , -1.5400241 , -1.3820282 ,
#         -1.22403229, -1.06603639, -0.90804049, -0.75004459, -0.59204869,
#         -0.43405278, -0.27605688, -0.11806098,  0.03993492,  0.19793082,
#          0.35592673,  0.51392263,  0.67191853,  0.82991443,  0.98791034,
#          1.14590624,  1.30390214,  1.46189804,  1.61989394,  1.77788985,
#          1.93588575,  2.09388165,  2.25187755,  2.40987345,  2.56786936,
#          2.72586526,  2.88386116,  3.04185706,  3.19985296,  3.35784887,
#          3.51584477]),
#  <BarContainer object of 40 artists>)
